# %% [markdown]
# # このファイルの目的
# BDIを原油価格、鉄鉱石価格、とうもろこし価格、中国経済指数から回帰させる

# %% [markdown]
# # データの期間について
# | データ| ファイル名    | 1行目        | 最終行  |
# |:-----------|------------:|:------------:|:------------:|
# | BCI| LLOYDS-BCI.csv |  2015-10-31   |2009-03-31|
# | BPI|LLOYDS-BPI.csv |   2015-10-31   |2009-03-31|
# | BSI|LLOYDS-BSI.csv | 2015-10-31  |2012-08-31|
# | Oil| CrudeOilPrice.csv |1986-01-01|2015-09-01|
# | Iron Ore| ODA-PIORECR_USD.csv |2015-11-30|1980-01-31|
# | Corn | TFGRAIN-CORN.csv |2015-12-31|2000-12-31|

# %%
import pandas as pd
# %matplotlib inline

# get file data and convert to dataframe
def get_data(filename):
    Data_LOCATION = (r'../data/%s'%filename)
    DF = pd.read_csv(Data_LOCATION) 
    try: # for BDI data
        DF["Date"] = pd.to_datetime(DF["Date"], '%Y-%m-%d')
    except: # for oil data
        DF["DATE"] = pd.to_datetime(DF["DATE"], '%Y-%m-%d')
        # reverse df
        DF = DF.iloc[::-1]
        DF.index = [range(len(DF))]
    return DF    

# revise the len(dfname) = len(kind_of_BDI)
def adjust_BDI(dfname, kind_of_BDI):
    df_target=get_data(dfname)
    df_BDI=get_data(kind_of_BDI)
    if dfname == "CrudeOilPrice.csv":
        if kind_of_BDI == "LLOYDS-BSI.csv":
            df_BDI=df_BDI[2:]
            df_BDI.index=[range(len(df_BDI))]
            result = pd.concat([df_target[:37],df_BDI],axis=1)
        else:
            result = pd.concat([df_target[:78],df_BDI[2:]],axis=1)
        return result
    else:
        result = pd.merge(df_target,df_BDI,on="Date")
        return result
            

#get_data("TFGRAIN-CORN.csv")

# %%
adjust_BDI("CrudeOilPrice.csv","LLOYDS-BSI.csv")
# Out:
#          DATE   VALUE       Date  BSI_Value
# 2  2015-07-01   50.90 2015-08-31        925
# 3  2015-06-01   59.82 2015-07-31        899
# 4  2015-05-01   59.27 2015-06-30        715
# 5  2015-04-01   54.45 2015-05-31        647
# 6  2015-03-01   47.82 2015-04-30        625
# 7  2015-02-01   50.58 2015-03-31        650
# 8  2015-01-01   47.22 2015-02-28        515
# 9  2014-12-01   59.29 2015-01-31        585
# 10 2014-11-01   75.79 2014-12-31        887
# 11 2014-10-01   84.40 2014-11-30        986
# 12 2014-09-01   93.21 2014-10-31        892
# 13 2014-08-01   96.54 2014-09-30       1051
# 14 2014-07-01  103.59 2014-08-31        970
# 15 2014-06-01  105.79 2014-07-31        716
# 16 2014-05-01  102.18 2014-06-30        675
# 17 2014-04-01  102.07 2014-05-31        830
# 18 2014-03-01  100.80 2014-04-30        919
# 19 2014-02-01  100.82 2014-03-31       1090
# 20 2014-01-01   94.62 2014-02-28       1103
# 21 2013-12-01   97.63 2014-01-31        996
# 22 2013-11-01   93.86 2013-12-31       1453
# 23 2013-10-01  100.54 2013-11-30       1475
# 24 2013-09-01  106.29 2013-10-31       1269
# 25 2013-08-01  106.57 2013-09-30       1079
# 26 2013-07-01  104.67 2013-08-31        939
# 27 2013-06-01   95.77 2013-07-31        912
# 28 2013-05-01   94.51 2013-06-30        954
# 29 2013-04-01   92.02 2013-05-31        871
# 30 2013-03-01   92.94 2013-04-30        888
# 31 2013-02-01   95.31 2013-03-31        944
# 32 2013-01-01   94.76 2013-02-28        764
# 33 2012-12-01   87.86 2013-01-31        684
# 34 2012-11-01   86.53 2012-12-31        728
# 35 2012-10-01   89.49 2012-11-30        766
# 36 2012-09-01   94.51 2012-10-31        678
